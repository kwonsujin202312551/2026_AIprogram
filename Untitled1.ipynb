# %%
print('나의 이름은 :', '권수진')
print('나의 나이는 :', '23')
print('나의 키는', 160, 'cm입니다.')
print('10+20=', 10+20)
print('10*20=', 10*20)
# Out:
# 나의 이름은 : 권수진
# 나의 나이는 : 23
# 나의 키는 160 cm입니다.
# 10+20= 30
# 10*20= 200

# %%
name = '권수진'
print('나의 이름은 :',name)
age = 23
print('나의 나이는 :', age)
height = 160
print('나의 키는', height, 'cm입니다')
sum = 10 + 20
print('10+20=', sum)
mult = 10*20
print('10*20=', mult)
# Out:
# 나의 이름은 : 권수진
# 나의 나이는 : 23
# 나의 키는 160 cm입니다
# 10+20= 30
# 10*20= 200

# %%
width = 20
height = 40
width = 30
area = width*height
print('사각형의 면적', area)
# Out:
# 사각형의 면적 1200

# %%
print(123*456)
print(1357+2468)
print(5**4)
print(10/4)
print(10//5)
print(10%5)
# Out:
# 56088
# 3825
# 625
# 2.5
# 2
# 0

# %%
print(5%2)
# Out:
# 1

# %%
x=2
y= 1/2
print(x**y)
# Out:
# 1.4142135623730951

# %%
x=3
y= 1/2
print(x**y)
# Out:
# 1.7320508075688772

# %%
a = 8 + 2j
b = 4 + 3j
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# (12+5j)
# (4-1j)
# (26+32j)
# (1.52-0.64j)

# %%
a=1024
print(a>>1)
print(a>>2)
a = a>>1
print(a)
a = a>>1
print(a)
a = 1
print(a<<1)
a = a<<1
print(a)
a = a<<1
print(a)
a = a<<1
print(a)
a = a<<1
print(a)
# Out:
# 512
# 256
# 512
# 256
# 2
# 2
# 4
# 8
# 16

# %%
name = input('이름을 입력하세요:')
print(name, '님이 입장하셨습니다.')
# Out:
# 이름을 입력하세요: 권수진
# 권수진 님이 입장하셨습니다.

# %%
m = int(input('숫자 m을 입력하세요 : '))
n = int(input('숫자 n을 입력하세요 : '))
print('m+n=', m+n)
print('m-n=', m-n)
# Out:
# 숫자 m을 입력하세요 :  30
# 숫자 n을 입력하세요 :  50
# m+n= 80
# m-n= -20

# %%
radius = int(input('원의 반지름을 입력하세요 : '))
print('원의 면적=', 3.14*radius*radius)
# Out:
# 원의 반지름을 입력하세요 :  4
# 원의 면적= 50.24
